# %% [markdown]
# <a href="https://colab.research.google.com/github/beeakma0-cpu/1f-grupo-A/blob/main/aula_PA_grupo_A_dia_28_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Laços e iteração

# %%
#Laços e iteração

print("Olá mundo")
print("Olá mundo")
print("Olá mundo")
print("Olá mundo")
print("Olá mundo")
print("Olá mundo")
# Out:
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo

# %%
for i in range (7):
 print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range (7):
  print(6 - i)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
#escrever um programa que imprime a palavra invertida

palavra = "python"
invertida = ""

for i in (palavra):

 invertida = i + invertida
print (invertida)
# Out:
# nohtyp

# %%
# Verifica se a palavra é um palíndromo

palavra = str(input("Digite uma palavra -->"))

if palavra == palavra[::-1]:

 print("Sua palavra é palíndroma")

else:
 print("Sua palavra não é palíndroma")
# Out:
# Digite uma palavra -->socorrammesubinoonibusemmarrocos
# Sua palavra é palíndroma

# %%
# outro jeito
 palavra = str(input("Digite uma palavra: "))
invertida = ""

for i in (palavra):
  invertida = i + invertida

# %%
#Escrever um programa que O usuário digita um número e o programa imprime os números pares de 0 até o número

numero = int(input("Digite um número: "))

for i in range ({numero}):

 print({numero} + i)
# Out:
# Digite um número: 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_754/2040893680.py in <cell line: 0>()
#       3 numero = int(input("Digite um número: "))
#       4
# ----> 5 for i in range ({numero}):
#       6
#       7  print({numero} + i)
#
# TypeError: 'set' object cannot be interpreted as an integer
