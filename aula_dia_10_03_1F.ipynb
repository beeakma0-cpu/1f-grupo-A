# %% [markdown]
# <a href="https://colab.research.google.com/github/beeakma0-cpu/1f-grupo-A/blob/main/aula_dia_10_03_1F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calcular a área do retângulo

# %%
# Entrada
Comprimento = float (input("Digite o comprimento do retângulo:"))
altura = float(input("Digite a altura do retângulo:"))

# Processamento

area = Comprimento * altura

# Saída

print (f"O total da área do retângulo é: {area}")
# Out:
# Digite o comprimento do retângulo:7
# Digite a altura do retângulo:3
# O total da área do retângulo é: 21.0

# %% [markdown]
#  Fazer um cadastro de usuário:
#   Objetivo: trabalhar com (str)
#
#   Entrada de dados: Nome e idade
#   Processamento: armazenar os dados
#   Saída: mostrar uma mendagem de Olá e a idade do usuário

# %%
# Entrada
Nome = str(input("digite seu nome:"))
idade = int(input(" Digite sua idade"))

# Saída

print (f"Olá {Nome}, seja Bem-vindo!")
print (f" você tem {idade} anos.")
# Out:
# digite seu nome:carlos
#  Digite sua idade67
# Olá carlos, seja Bem-vindo!
#  você tem 67 anos.

# %% [markdown]
# Fazer um programa que calcula o dobro de um número
#
#  Entrada: um número
#
# Processamento: calcular o dobro
#
# Saída: mostrar o resultado

# %%
# Entrada

Numero = int (input("Digite um Número:"))

 # Processamento

Dobro = Numero * 2

 # Saída

print (f"o dobro do numero {Numero} é igual a {Dobro}")
# Out:
# Digite um Número:5555554
# o dobro do numero 5555554 é igual a 11111108

# %% [markdown]
# Escrever um programa que calcula a media das notas do aluno
#
# Entrada: nome, idade e as 04 notas do bimestre
#
# Processamento: calcular a media
#
# Saída: mostrar o nome do aluno e a media obtida

# %%
# Entrada

Nome = str(input("Digite seu nome:"))
Idade = int(input("Digite sua idade:"))
notas = int(input("Digite suas 04 notas do bimestre"))
notas = int(input("Digite suas 04 notas do bimestre"))
notas = int(input("Digite suas 04 notas do bimestre"))
notas = int(input("Digite suas 04 notas do bimestre"))

# Processamento

media = notas + notas + notas + notas
notas/4

# Saída

print (f"Olá {Nome}, sua media obtida foi {media}")
# Out:
# Digite seu nome:b
# Digite sua idade:11
# Digite suas 04 notas do bimestre9
# Digite suas 04 notas do bimestre9
# Digite suas 04 notas do bimestre9
# Digite suas 04 notas do bimestre9
# Olá b, sua media obtida foi 36
